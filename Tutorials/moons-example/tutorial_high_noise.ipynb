# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import gzip

import torch
import torch.nn as nn
import torch.nn.functional as F

import pickle

import numpy as np

import matplotlib.pyplot as plt

import random


import HMNN

# %%
# Set font properties for ticks
plt.rcParams['xtick.labelsize'] = 18  # Font size of x-axis tick labels
plt.rcParams['ytick.labelsize'] = 18  # Font size of y-axis tick labels

# Set font properties for labels
plt.rcParams['axes.labelsize'] = 24  # Font size of axis labels

# Set font properties for title
plt.rcParams['axes.titlesize'] = 24  # Font size of title

# %% [markdown]
# Generate the data

# %%
def rotation_matrix(angle):

	return np.array([[np.cos(angle), -np.sin(angle)],[np.sin(angle), np.cos(angle)]])

# %%
angles = np.pi*np.linspace(0, 4, 5)/4

sample_size = 10000
X_raw, y_raw = make_moons(n_samples=5*sample_size, noise=0.3, random_state=42)

X = np.zeros((np.shape(X_raw)[0], 2))
for t in range(5):
	X[t*sample_size:(t*sample_size+sample_size),:] = np.einsum("nk,kj->nj", X_raw[t*sample_size:(t*sample_size+sample_size),:], rotation_matrix(angles[t]))

y = y_raw

# %%
sample_size = 10000
X_raw, y_raw = make_moons(n_samples=5*sample_size, noise=0.3, random_state=42)

X_val = np.zeros((np.shape(X_raw)[0], 2))
for t in range(5):
	X_val[t*sample_size:(t*sample_size+sample_size),:] = np.einsum("nk,kj->nj", X_raw[t*sample_size:(t*sample_size+sample_size),:], rotation_matrix(angles[t]))

y_val = y_raw

# %%
fig, ax = plt.subplots(1, 5, figsize=(25, 5))

for t in range(5):

	ax[t].scatter(X[t*sample_size:(t*sample_size+sample_size),0], X[t*sample_size:(t*sample_size+sample_size),1], c = np.array(["red", "black"])[y[t*sample_size:(t*sample_size+sample_size)]])
	# ax[t].set_xlabel("x")

	ax[t].set_title("Time "+str(t))

	# if t==0:
	# 	ax[t].set_ylabel("y")
	# ax[1,t].scatter(X_val[t*sample_size:(t*sample_size+sample_size),0], X_val[t*sample_size:(t*sample_size+sample_size),1], c = y_val[t*sample_size:(t*sample_size+sample_size)])

	
plt.savefig('moonoverlap_data.png', dpi=100)

# %%
# The minibatch size
minibatch_size = 256
# The number of epochs

epocs          = 100 
# This parameter if use to retrain on part of the previous data. 
# If sliding = sample_size then we move to a new set of data.
sliding = sample_size
# Number of Sequential training we want to do minus 1
T = 5

###########################################################
# Set the network structure
# Depth
L = 4
# Structure of the hidden units
architecture = np.array([2, 50, 50, 2])

# Kernel parameter of the HMNN
alpha_k = 0.5
sigma_k = np.exp(-2)
c       = np.exp(5)
pi      = 0.5

# Mixture weight for the variational dropconnect
p       = 0.75

# Learning rate
lr_c = 1e-3

# Size of the Monte Carlo sample
mc_c = 1

# %%
# %run -i HMNN.py

# %%
# Loss function
loss_function = torch.nn.CrossEntropyLoss(reduction = 'sum')


HMMNET = torchHHMnet(architecture, alpha_k, sigma_k, c, pi, p, loss_function, sample_size, minibatch_size, epocs, T, sliding, workers = 4)

HMMNET.forward_pass(X, y, X_val, y_val, lr_c, mc_c)
# Out:
# Time  1
# Epoch  1
# Prior score  72.02715313974069  and Data score  151.00163786356347
# Performance on the validation set  0.8196
# Epoch  2
# Prior score  71.68772175960325  and Data score  104.3568284272116
# Performance on the validation set  0.8472
# Epoch  3
# Prior score  71.74875120869795  and Data score  98.51554405952217
# Performance on the validation set  0.8433
# Epoch  4
# Prior score  71.05153263965862  and Data score  92.87786083137202
# Performance on the validation set  0.8556
# Epoch  5
# Prior score  71.31528298519395  and Data score  90.7635440659409
# Performance on the validation set  0.8613
# Epoch  6
# Prior score  71.01257705518054  and Data score  89.63552160211192
# Performance on the validation set  0.862
# Epoch  7
# Prior score  70.46984768114211  and Data score  87.72720529214929
# Performance on the validation set  0.8672
# Epoch  8
# Prior score  70.35011988836631  and Data score  91.20899894605523
# Performance on the validation set  0.8677
# Epoch  9
# Prior score  70.19172621727766  and Data score  87.21857002174646
# Performance on the validation set  0.8734
# Epoch  10
# Prior score  70.26804830055382  and Data score  85.75868917923536
# Performance on the validation set  0.8771
# Epoch  11
# Prior score  70.1217888666506  and Data score  85.37368554220905
# Performance on the validation set  0.8781
# Epoch  12
# Prior score  69.62961555134711  and Data score  85.2630582919507
# Performance on the validation set  0.8724
# Epoch  13
# Prior score  69.62071557602376  and Data score  82.26256859955184
# Performance on the validation set  0.8815
# Epoch  14
# Prior score  69.45738604618688  and Data score  82.84321849052691
# Performance on the validation set  0.8805
# Epoch  15
# Prior score  69.32839262637538  and Data score  81.06398082629626
# Performance on the validation set  0.8751
# Epoch  16
# Prior score  69.30969071598555  and Data score  81.33439130725147
# Performance on the validation set  0.8843
# Epoch  17
# Prior score  68.97151016497143  and Data score  80.46875451881432
# Performance on the validation set  0.8838
# Epoch  18
# Prior score  68.3548185781647  and Data score  78.82154359712152
# Performance on the validation set  0.8911
# Epoch  19
# Prior score  68.71583379514497  and Data score  80.29497112712174
# Performance on the validation set  0.8956
# Epoch  20
# Prior score  68.67917696289409  and Data score  78.79690742914994
# Performance on the validation set  0.8982
# Epoch  21
# Prior score  68.5450607987024  and Data score  78.55146157800849
# Performance on the validation set  0.8978
# Epoch  22
# Prior score  67.95625969217008  and Data score  76.52069659908571
# Performance on the validation set  0.9003
# Epoch  23
# Prior score  68.31928544383085  and Data score  77.56131102621862
# Performance on the validation set  0.8978
# Epoch  24
# Prior score  68.18177830895117  and Data score  78.71847124731279
# Performance on the validation set  0.9006
# Epoch  25
# Prior score  68.17554483282424  and Data score  78.56712727448203
# Performance on the validation set  0.8956
# Epoch  26
# Prior score  67.55303542646305  and Data score  78.51556118012907
# Performance on the validation set  0.8992
# Epoch  27
# Prior score  67.52802327957895  and Data score  75.32669590385801
# Performance on the validation set  0.8965
# Epoch  28
# Prior score  67.39301036927135  and Data score  76.96657868844942
# Performance on the validation set  0.8973
# Epoch  29
# Prior score  67.26576678224576  and Data score  74.36980946666785
# Performance on the validation set  0.8991
# Epoch  30
# Prior score  67.24676406157175  and Data score  74.34320304869352
# Performance on the validation set  0.9036
# Epoch  31
# Prior score  67.25838342556303  and Data score  73.65568338012862
# Performance on the validation set  0.8964
# Epoch  32
# Prior score  66.8588272503256  and Data score  75.03850402914256
# Performance on the validation set  0.9074
# Epoch  33
# Prior score  66.94315114265322  and Data score  72.93405828733313
# Performance on the validation set  0.9054
# Epoch  34
# Prior score  66.70578977585946  and Data score  75.93371771593222
# Performance on the validation set  0.9034
# Epoch  35
# Prior score  66.48928143109612  and Data score  74.51755292094072
# Performance on the validation set  0.902
# Epoch  36
# Prior score  66.54325700222907  and Data score  75.85096537762175
# Performance on the validation set  0.9039
# Epoch  37
# Prior score  66.42550486525339  and Data score  70.8507416568986
# Performance on the validation set  0.9047
# Epoch  38
# Prior score  66.57706817090687  and Data score  71.14814990361211
# Performance on the validation set  0.9035
# Epoch  39
# Prior score  66.21692163832999  and Data score  72.69192290005408
# Performance on the validation set  0.906
# Epoch  40
# Prior score  66.16092969412749  and Data score  73.30102782539475
# Performance on the validation set  0.9088
# Epoch  41
# Prior score  66.09685579450162  and Data score  72.60814282414195
# Performance on the validation set  0.9065
# Epoch  42
# Prior score  65.72011926183433  and Data score  70.28250700438798
# Performance on the validation set  0.9096
# Epoch  43
# Prior score  65.76290071016948  and Data score  72.39096447650516
# Performance on the validation set  0.9107
# Epoch  44
# Prior score  65.65237499522205  and Data score  69.96699851173678
# Performance on the validation set  0.9101
# Epoch  45
# Prior score  65.45873545460373  and Data score  70.90944839761876
# Performance on the validation set  0.9096
# Epoch  46
# Prior score  65.43599077150212  and Data score  71.11658756457429
# Performance on the validation set  0.9071
# Epoch  47
# Prior score  65.5795505870499  and Data score  68.56733004224903
# Performance on the validation set  0.9122
# Epoch  48
# Prior score  65.34895881574111  and Data score  70.47838203096376
# Performance on the validation set  0.9106
# Epoch  49
# Prior score  65.49650904841965  and Data score  70.42987567694091
# Performance on the validation set  0.9125
# Epoch  50
# Prior score  64.95502546261478  and Data score  69.67522621921165
# Performance on the validation set  0.9109
# Epoch  51
# Prior score  65.23565731958276  and Data score  68.41664131011844
# Performance on the validation set  0.912
# Epoch  52
# Prior score  64.54502262710623  and Data score  70.35454108903882
# Performance on the validation set  0.9122
# Epoch  53
# Prior score  64.74705393463205  and Data score  70.21748767285581
# Performance on the validation set  0.9124
# Epoch  54
# Prior score  64.95828338814067  and Data score  68.01694924320888
# Performance on the validation set  0.912
# Epoch  55
# Prior score  64.42231514305178  and Data score  68.0155749601538
# Performance on the validation set  0.9119
# Epoch  56
# Prior score  64.85478374664629  and Data score  71.60442905332727
# Performance on the validation set  0.9119
# Epoch  57
# Prior score  64.62320424594176  and Data score  71.73108348290388
# Performance on the validation set  0.9125
# Epoch  58
# Prior score  64.37180481671452  and Data score  68.6370313734699
# Performance on the validation set  0.9077
# Epoch  59
# Prior score  64.513477892637  and Data score  68.88003959247254
# Performance on the validation set  0.9095
# Epoch  60
# Prior score  64.08461257818178  and Data score  68.07229777151323
# Performance on the validation set  0.9099
# Epoch  61
# Prior score  64.09301065923093  and Data score  68.61956570377025
# Performance on the validation set  0.9113
# Epoch  62
# Prior score  63.789140728081925  and Data score  69.25480029081184
# Performance on the validation set  0.9131
# Epoch  63
# Prior score  64.07652070025729  and Data score  68.60683658501522
# Performance on the validation set  0.9061
# Epoch  64
# Prior score  63.64203616608287  and Data score  68.46988539876124
# Performance on the validation set  0.9106
# Epoch  65
# Prior score  63.39915203596765  and Data score  68.826577935886
# Performance on the validation set  0.913
# Epoch  66
# Prior score  63.63517161330943  and Data score  69.85984691423405
# Performance on the validation set  0.9122
# Epoch  67
# Prior score  63.56960253874717  and Data score  68.42554739646705
# Performance on the validation set  0.9107
# Epoch  68
# Prior score  63.550080027068965  and Data score  66.69499903149816
# Performance on the validation set  0.9113
# Epoch  69
# Prior score  63.11644856737796  and Data score  68.21234411913976
# Performance on the validation set  0.9094
# Epoch  70
# Prior score  63.300994326412585  and Data score  67.10368379048079
# Performance on the validation set  0.9115
# Epoch  71
# Prior score  63.237364820074504  and Data score  67.68338933823503
# Performance on the validation set  0.9119
# Epoch  72
# Prior score  63.21048105778058  and Data score  69.7769953906363
# Performance on the validation set  0.9102
# Epoch  73
# Prior score  63.03006081276995  and Data score  67.14360728202465
# Performance on the validation set  0.9117
# Epoch  74
# Prior score  63.259549849171435  and Data score  69.53923625727518
# Performance on the validation set  0.9097
# Epoch  75
# Prior score  62.64379792229612  and Data score  66.18874051814676
# Performance on the validation set  0.9117
# Epoch  76
# Prior score  63.00608261047286  and Data score  67.59160275306168
# Performance on the validation set  0.9127
# Epoch  77
# Prior score  62.89168315074325  and Data score  67.82809297721526
# Performance on the validation set  0.9099
# Epoch  78
# Prior score  62.783742715433505  and Data score  67.72413367801404
# Performance on the validation set  0.9087
# Epoch  79
# Prior score  62.775781407824375  and Data score  66.96971252522596
# Performance on the validation set  0.9117
# Epoch  80
# Prior score  62.56486395021609  and Data score  67.79032714190782
# Performance on the validation set  0.912
# Epoch  81
# Prior score  62.80728442302003  and Data score  68.91950880945086
# Performance on the validation set  0.9113
# Epoch  82
# Prior score  62.4684430184094  and Data score  69.7342367436403
# Performance on the validation set  0.912
# Epoch  83
# Prior score  62.57083514989008  and Data score  66.94115906392837
# Performance on the validation set  0.9134
# Epoch  84
# Prior score  62.18133266322831  and Data score  71.31854230060735
# Performance on the validation set  0.9111
# Epoch  85
# Prior score  62.32043342191484  and Data score  66.76849535198167
# Performance on the validation set  0.9137
# Epoch  86
# Prior score  61.8468321278254  and Data score  70.00351677575115
# Performance on the validation set  0.9132
# Epoch  87
# Prior score  62.24624536212324  and Data score  69.03327954071466
# Performance on the validation set  0.9121
# Epoch  88
# Prior score  62.35905468697787  and Data score  68.69157665359117
# Performance on the validation set  0.9124
# Epoch  89
# Prior score  62.169228753344946  and Data score  67.64170303647266
# Performance on the validation set  0.9112
# Epoch  90
# Prior score  61.846688774430554  and Data score  68.3849045039091
# Performance on the validation set  0.9115
# Epoch  91
# Prior score  61.93294726068025  and Data score  66.18031448964409
# Performance on the validation set  0.9102
# Epoch  92
# Prior score  61.75306967816088  and Data score  71.55868565563537
# Performance on the validation set  0.9127
# Epoch  93
# Prior score  61.67828302488189  and Data score  70.1323397957696
# Performance on the validation set  0.9126
# Epoch  94
# Prior score  61.73134294511397  and Data score  72.35630853906092
# Performance on the validation set  0.9122
# Epoch  95
# Prior score  61.87297656797294  and Data score  68.78549716672605
# Performance on the validation set  0.9124
# Epoch  96
# Prior score  61.55304210427587  and Data score  65.52110762062476
# Performance on the validation set  0.9109
# Epoch  97
# Prior score  61.230972737029646  and Data score  68.48775492087722
# Performance on the validation set  0.9121
# Epoch  98
# Prior score  61.56555615491699  and Data score  70.25559587852341
# Performance on the validation set  0.9125
# Epoch  99
# Prior score  61.378741633391606  and Data score  67.68152775040416
# Performance on the validation set  0.9129
# Epoch  100
# Prior score  61.32020199132554  and Data score  66.59328592691658
# Performance on the validation set  0.9119
# Time  2
# Epoch  1
# Prior score  10.930633254296964  and Data score  89.63820462875293
# Performance on the validation set  0.8813
# Epoch  2
# Prior score  11.341412489399728  and Data score  78.67863090509162
# Performance on the validation set  0.888
# Epoch  3
# Prior score  11.576441606580463  and Data score  75.80328971490917
# Performance on the validation set  0.8916
# Epoch  4
# Prior score  12.292234170727953  and Data score  79.84804327013154
# Performance on the validation set  0.8983
# Epoch  5
# Prior score  12.32829146875493  and Data score  72.59917436957534
# Performance on the validation set  0.9044
# Epoch  6
# Prior score  12.53080347090274  and Data score  73.1496242823517
# Performance on the validation set  0.9056
# Epoch  7
# Prior score  12.552617894188955  and Data score  73.92072293801208
# Performance on the validation set  0.8984
# Epoch  8
# Prior score  12.935007372235933  and Data score  70.7086325202423
# Performance on the validation set  0.8948
# Epoch  9
# Prior score  12.742070762957779  and Data score  70.92999539073585
# Performance on the validation set  0.9088
# Epoch  10
# Prior score  13.031632391971755  and Data score  70.4774143748373
# Performance on the validation set  0.9051
# Epoch  11
# Prior score  13.287492905742129  and Data score  71.02979646493898
# Performance on the validation set  0.9082
# Epoch  12
# Prior score  13.13692067136812  and Data score  71.74881774146914
# Performance on the validation set  0.9096
# Epoch  13
# Prior score  13.449790217433547  and Data score  71.8416602883241
# Performance on the validation set  0.9082
# Epoch  14
# Prior score  13.522197515860698  and Data score  67.76344455797526
# Performance on the validation set  0.9137
# Epoch  15
# Prior score  13.483089465486518  and Data score  73.29383935678901
# Performance on the validation set  0.9084
# Epoch  16
# Prior score  13.725598484347255  and Data score  71.26861419357947
# Performance on the validation set  0.9063
# Epoch  17
# Prior score  13.591472109585306  and Data score  68.70140634744072
# Performance on the validation set  0.9072
# Epoch  18
# Prior score  13.630095310028628  and Data score  69.34871952095725
# Performance on the validation set  0.9084
# Epoch  19
# Prior score  13.667424843055496  and Data score  71.30767643586165
# Performance on the validation set  0.9109
# Epoch  20
# Prior score  13.742053720257509  and Data score  70.3735144929782
# Performance on the validation set  0.91
# Epoch  21
# Prior score  13.62725999331523  and Data score  74.64711104427408
# Performance on the validation set  0.9118
# Epoch  22
# Prior score  13.855576640958356  and Data score  71.32210892494527
# Performance on the validation set  0.9109
# Epoch  23
# Prior score  14.068471710947355  and Data score  69.60004451932174
# Performance on the validation set  0.9093
# Epoch  24
# Prior score  13.683722343674068  and Data score  68.88918577293681
# Performance on the validation set  0.9104
# Epoch  25
# Prior score  13.685065837188422  and Data score  68.63481549024853
# Performance on the validation set  0.9116
# Epoch  26
# Prior score  13.876811652921447  and Data score  67.25879466766001
# Performance on the validation set  0.912
# Epoch  27
# Prior score  13.775083982741835  and Data score  67.54442596377004
# Performance on the validation set  0.9069
# Epoch  28
# Prior score  14.0146457449154  and Data score  71.43239048696266
# Performance on the validation set  0.9126
# Epoch  29
# Prior score  13.89877826967078  and Data score  68.53518346581212
# Performance on the validation set  0.9117
# Epoch  30
# Prior score  13.68035283283091  and Data score  69.54481686804792
# Performance on the validation set  0.9134
# Epoch  31
# Prior score  13.994945550304593  and Data score  71.67283845928598
# Performance on the validation set  0.9134
# Epoch  32
# Prior score  13.77227686088183  and Data score  69.35245334171304
# Performance on the validation set  0.9069
# Epoch  33
# Prior score  13.662123251577036  and Data score  71.52063929696756
# Performance on the validation set  0.9084
# Epoch  34
# Prior score  13.753731013989864  and Data score  67.76426272408978
# Performance on the validation set  0.9083
# Epoch  35
# Prior score  13.554076250411246  and Data score  68.98173962181784
# Performance on the validation set  0.9109
# Epoch  36
# Prior score  13.671290498807558  and Data score  68.8252499433565
# Performance on the validation set  0.9116
# Epoch  37
# Prior score  13.983310413759726  and Data score  71.18764635297795
# Performance on the validation set  0.9119
# Epoch  38
# Prior score  13.831890116235948  and Data score  69.67340322434461
# Performance on the validation set  0.9085
# Epoch  39
# Prior score  13.740013985839814  and Data score  69.41746152753741
# Performance on the validation set  0.9096
# Epoch  40
# Prior score  13.919444585730425  and Data score  70.19828181452358
# Performance on the validation set  0.9108
# Epoch  41
# Prior score  13.870433080978637  and Data score  66.14151140968565
# Performance on the validation set  0.9117
# Epoch  42
# Prior score  13.885879025532637  and Data score  72.78078439230197
# Performance on the validation set  0.9102
# Epoch  43
# Prior score  13.96883585261725  and Data score  69.71210376929356
# Performance on the validation set  0.9077
# Epoch  44
# Prior score  13.923396343929332  and Data score  71.18440351527764
# Performance on the validation set  0.9106
# Epoch  45
# Prior score  13.962121221604676  and Data score  69.28360944532906
# Performance on the validation set  0.9103
# Epoch  46
# Prior score  13.837506900334224  and Data score  68.29042287412392
# Performance on the validation set  0.9121
# Epoch  47
# Prior score  13.833408232792145  and Data score  67.025065389723
# Performance on the validation set  0.9119
# Epoch  48
# Prior score  14.113063173255329  and Data score  66.42863510134191
# Performance on the validation set  0.9142
# Epoch  49
# Prior score  13.816938765406395  and Data score  66.74602845619413
# Performance on the validation set  0.9121
# Epoch  50
# Prior score  13.922693417026109  and Data score  68.9279482164881
# Performance on the validation set  0.9138
# Epoch  51
# Prior score  13.677614702091432  and Data score  67.8046789940562
# Performance on the validation set  0.9117
# Epoch  52
# Prior score  14.050032630047735  and Data score  70.65084419342257
# Performance on the validation set  0.9087
# Epoch  53
# Prior score  13.648541710120243  and Data score  66.88640251892699
# Performance on the validation set  0.9126
# Epoch  54
# Prior score  13.781744855039696  and Data score  67.88031667266966
# Performance on the validation set  0.9141
# Epoch  55
# Prior score  13.927441243487387  and Data score  67.62814783789122
# Performance on the validation set  0.91
# Epoch  56
# Prior score  13.777683121125424  and Data score  68.59011360379591
# Performance on the validation set  0.9123
# Epoch  57
# Prior score  13.844350262838676  and Data score  68.77565296757898
# Performance on the validation set  0.9102
# Epoch  58
# Prior score  13.873810300902177  and Data score  67.64307158944808
# Performance on the validation set  0.9122
# Epoch  59
# Prior score  13.940452013470162  and Data score  68.0072022442857
# Performance on the validation set  0.9131
# Epoch  60
# Prior score  13.596539873400319  and Data score  69.09894516233719
# Performance on the validation set  0.9132
# Epoch  61
# Prior score  13.70150098986891  and Data score  71.11176061954545
# Performance on the validation set  0.9108
# Epoch  62
# Prior score  13.673883902670463  and Data score  70.77037200763253
# Performance on the validation set  0.9071
# Epoch  63
# Prior score  14.096831852268206  and Data score  68.0834531839457
# Performance on the validation set  0.9131
# Epoch  64
# Prior score  13.835341990160387  and Data score  70.6132601579205
# Performance on the validation set  0.9121
# Epoch  65
# Prior score  13.96420219850951  and Data score  72.28774575089017
# Performance on the validation set  0.909
# Epoch  66
# Prior score  13.761599269038669  and Data score  69.47870673221838
# Performance on the validation set  0.9116
# Epoch  67
# Prior score  13.999536499140177  and Data score  69.11377843705554
# Performance on the validation set  0.9107
# Epoch  68
# Prior score  13.961912604208619  and Data score  73.56989940171549
# Performance on the validation set  0.9123
# Epoch  69
# Prior score  13.677788011542647  and Data score  67.74584959035944
# Performance on the validation set  0.9131
# Epoch  70
# Prior score  13.818131170605906  and Data score  67.27840238815749
# Performance on the validation set  0.9118
# Epoch  71
# Prior score  14.184774812589065  and Data score  68.05054475138245
# Performance on the validation set  0.9107
# Epoch  72
# Prior score  13.87358322868381  and Data score  68.92039752622198
# Performance on the validation set  0.9121
# Epoch  73
# Prior score  14.208846356011396  and Data score  67.96303488541658
# Performance on the validation set  0.9125
# Epoch  74
# Prior score  13.694569951122526  and Data score  71.63119332954464
# Performance on the validation set  0.9146
# Epoch  75
# Prior score  13.813121271075206  and Data score  70.05401829867323
# Performance on the validation set  0.9131
# Epoch  76
# Prior score  13.764205204291974  and Data score  65.77301159066444
# Performance on the validation set  0.9134
# Epoch  77
# Prior score  13.916350211744508  and Data score  67.0253695364008
# Performance on the validation set  0.9117
# Epoch  78
# Prior score  13.737475715711135  and Data score  67.57851729117097
# Performance on the validation set  0.9122
# Epoch  79
# Prior score  13.845419873409837  and Data score  66.84171980924526
# Performance on the validation set  0.9128
# Epoch  80
# Prior score  13.912907999589951  and Data score  69.78590629656962
# Performance on the validation set  0.9074
# Epoch  81
# Prior score  13.774543946483233  and Data score  69.94091036948124
# Performance on the validation set  0.9119
# Epoch  82
# Prior score  13.670639980136315  and Data score  70.49397370175656
# Performance on the validation set  0.9082
# Epoch  83
# Prior score  14.031979393176366  and Data score  70.39557571523771
# Performance on the validation set  0.9101
# Epoch  84
# Prior score  13.72297140166505  and Data score  68.56852193044314
# Performance on the validation set  0.9129
# Epoch  85
# Prior score  13.605582267151362  and Data score  68.11700691921551
# Performance on the validation set  0.9067
# Epoch  86
# Prior score  14.005195218658356  and Data score  68.09891245971797
# Performance on the validation set  0.9133
# Epoch  87
# Prior score  13.787850003001239  and Data score  70.42102796399371
# Performance on the validation set  0.9108
# Epoch  88
# Prior score  14.017654574226007  and Data score  71.08473647368292
# Performance on the validation set  0.9095
# Epoch  89
# Prior score  13.665587832323517  and Data score  67.0823188843086
# Performance on the validation set  0.9034
# Epoch  90
# Prior score  13.78835635581368  and Data score  68.72027037271043
# Performance on the validation set  0.9057
# Epoch  91
# Prior score  13.998207803148007  and Data score  67.51388479524354
# Performance on the validation set  0.9123
# Epoch  92
# Prior score  13.640992852867297  and Data score  69.49794430414525
# Performance on the validation set  0.9099
# Epoch  93
# Prior score  13.81900814496154  and Data score  70.1535069860659
# Performance on the validation set  0.91
# Epoch  94
# Prior score  13.74836220627447  and Data score  70.26078283007621
# Performance on the validation set  0.9127
# Epoch  95
# Prior score  13.643463978201945  and Data score  69.5421094679711
# Performance on the validation set  0.9083
# Epoch  96
# Prior score  13.908583301719272  and Data score  69.88345246989967
# Performance on the validation set  0.9097
# Epoch  97
# Prior score  13.720810872228977  and Data score  68.8459428187645
# Performance on the validation set  0.9115
# Epoch  98
# Prior score  14.03459592448395  and Data score  71.99051305947205
# Performance on the validation set  0.9115
# Epoch  99
# Prior score  13.971218459936685  and Data score  68.76866424594661
# Performance on the validation set  0.9123
# Epoch  100
# Prior score  13.863017787602463  and Data score  70.31240167183218
# Performance on the validation set  0.9065
# Time  3
# Epoch  1
# Prior score  10.689320154543742  and Data score  98.41001647964839
# Performance on the validation set  0.8709
# Epoch  2
# Prior score  11.623539806268196  and Data score  81.00729955308086
# Performance on the validation set  0.884
# Epoch  3
# Prior score  12.325372197828667  and Data score  74.80514550457815
# Performance on the validation set  0.8902
# Epoch  4
# Prior score  12.593778133310137  and Data score  76.90042229917333
# Performance on the validation set  0.9007
# Epoch  5
# Prior score  12.976535284427671  and Data score  73.42835811731942
# Performance on the validation set  0.8996
# Epoch  6
# Prior score  13.080210525907647  and Data score  73.22476200075533
# Performance on the validation set  0.902
# Epoch  7
# Prior score  13.463484836847378  and Data score  73.60934011205904
# Performance on the validation set  0.9032
# Epoch  8
# Prior score  13.188608862134853  and Data score  72.25046363321334
# Performance on the validation set  0.9043
# Epoch  9
# Prior score  13.508813917814983  and Data score  73.02901400081532
# Performance on the validation set  0.9068
# Epoch  10
# Prior score  13.559454446739863  and Data score  72.06079679110951
# Performance on the validation set  0.9068
# Epoch  11
# Prior score  13.847077505360275  and Data score  75.88736505669299
# Performance on the validation set  0.9072
# Epoch  12
# Prior score  13.760450751890325  and Data score  74.41881719669608
# Performance on the validation set  0.9051
# Epoch  13
# Prior score  13.885743803405656  and Data score  70.65810717982154
# Performance on the validation set  0.9048
# Epoch  14
# Prior score  14.065859303925599  and Data score  70.27890708458042
# Performance on the validation set  0.9097
# Epoch  15
# Prior score  13.903886995229337  and Data score  69.23928349010062
# Performance on the validation set  0.9103
# Epoch  16
# Prior score  13.926984049059238  and Data score  69.97052482925132
# Performance on the validation set  0.9072
# Epoch  17
# Prior score  14.098646322428927  and Data score  70.08162104122327
# Performance on the validation set  0.9078
# Epoch  18
# Prior score  13.890629233495373  and Data score  69.34844534631024
# Performance on the validation set  0.9081
# Epoch  19
# Prior score  13.976319649669167  and Data score  69.85935658553323
# Performance on the validation set  0.9109
# Epoch  20
# Prior score  13.947309868536848  and Data score  70.8185764414992
# Performance on the validation set  0.9067
# Epoch  21
# Prior score  14.016095441744095  and Data score  71.05131870512385
# Performance on the validation set  0.9051
# Epoch  22
# Prior score  14.12450691123713  and Data score  68.93857967317487
# Performance on the validation set  0.9117
# Epoch  23
# Prior score  14.312483683081426  and Data score  71.90113286413819
# Performance on the validation set  0.9044
# Epoch  24
# Prior score  14.236291207800537  and Data score  70.49203006413117
# Performance on the validation set  0.9095
# Epoch  25
# Prior score  14.225977580951557  and Data score  67.9215210246579
# Performance on the validation set  0.9107
# Epoch  26
# Prior score  14.323887872372161  and Data score  68.69674080987733
# Performance on the validation set  0.9114
# Epoch  27
# Prior score  13.991535512748186  and Data score  68.9889637166466
# Performance on the validation set  0.9103
# Epoch  28
# Prior score  14.015194153147517  and Data score  68.93222368839787
# Performance on the validation set  0.9059
# Epoch  29
# Prior score  14.024026349518786  and Data score  68.00923156338182
# Performance on the validation set  0.9006
# Epoch  30
# Prior score  13.95855392790359  and Data score  68.93647774056429
# Performance on the validation set  0.9094
# Epoch  31
# Prior score  13.956990280074907  and Data score  70.72369083512434
# Performance on the validation set  0.9096
# Epoch  32
# Prior score  14.040842789030213  and Data score  68.35062858749215
# Performance on the validation set  0.9093
# Epoch  33
# Prior score  14.13314688020268  and Data score  68.20831280054065
# Performance on the validation set  0.9099
# Epoch  34
# Prior score  14.075090188236423  and Data score  68.75326708720957
# Performance on the validation set  0.9092
# Epoch  35
# Prior score  13.950914485713497  and Data score  72.53551418563127
# Performance on the validation set  0.9084
# Epoch  36
# Prior score  13.907810375191653  and Data score  70.17960156221777
# Performance on the validation set  0.9104
# Epoch  37
# Prior score  14.086958177161149  and Data score  68.37794461297582
# Performance on the validation set  0.9086
# Epoch  38
# Prior score  13.939170231675584  and Data score  69.53555745496901
# Performance on the validation set  0.9096
# Epoch  39
# Prior score  14.160214227375528  and Data score  70.05109463049824
# Performance on the validation set  0.9088
# Epoch  40
# Prior score  14.120854968915301  and Data score  69.6871137668542
# Performance on the validation set  0.9098
# Epoch  41
# Prior score  14.03934643254897  and Data score  67.2914798723895
# Performance on the validation set  0.9086
# Epoch  42
# Prior score  14.024886934755154  and Data score  70.44746666689012
# Performance on the validation set  0.9085
# Epoch  43
# Prior score  13.890661059158989  and Data score  69.75146839529432
# Performance on the validation set  0.9108
# Epoch  44
# Prior score  13.915948748946809  and Data score  68.59032515083321
# Performance on the validation set  0.9087
# Epoch  45
# Prior score  13.955167763916707  and Data score  71.85112694178903
# Performance on the validation set  0.9044
# Epoch  46
# Prior score  13.81204568325424  and Data score  69.65404512930616
# Performance on the validation set  0.9067
# Epoch  47
# Prior score  13.816658033058353  and Data score  69.17076317564717
# Performance on the validation set  0.9095
# Epoch  48
# Prior score  14.00808591195006  and Data score  68.86575020126588
# Performance on the validation set  0.9085
# Epoch  49
# Prior score  13.950477979835036  and Data score  69.62133138645952
# Performance on the validation set  0.9088
# Epoch  50
# Prior score  13.858230394281508  and Data score  69.66178080402979
# Performance on the validation set  0.9109
# Epoch  51
# Prior score  14.049137463560214  and Data score  68.09965474802243
# Performance on the validation set  0.9099
# Epoch  52
# Prior score  13.775585633887436  and Data score  69.55655793184512
# Performance on the validation set  0.9101
# Epoch  53
# Prior score  13.782561116238497  and Data score  67.36466647822685
# Performance on the validation set  0.9061
# Epoch  54
# Prior score  14.008661328605  and Data score  67.80509571136857
# Performance on the validation set  0.9097
# Epoch  55
# Prior score  13.788819277329976  and Data score  70.46550506449327
# Performance on the validation set  0.9098
# Epoch  56
# Prior score  14.006834538700796  and Data score  68.11078521208356
# Performance on the validation set  0.9089
# Epoch  57
# Prior score  13.70227074532701  and Data score  70.27536114091875
# Performance on the validation set  0.91
# Epoch  58
# Prior score  13.909513572042442  and Data score  69.24892605166386
# Performance on the validation set  0.9095
# Epoch  59
# Prior score  13.69126819337559  and Data score  67.38200124055271
# Performance on the validation set  0.9109
# Epoch  60
# Prior score  13.901003971141904  and Data score  68.11826469816314
# Performance on the validation set  0.9098
# Epoch  61
# Prior score  13.84514348517028  and Data score  66.61591899311559
# Performance on the validation set  0.91
# Epoch  62
# Prior score  13.891809215703516  and Data score  69.5685337343087
# Performance on the validation set  0.9108
# Epoch  63
# Prior score  14.142430026094836  and Data score  67.55114651280574
# Performance on the validation set  0.9111
# Epoch  64
# Prior score  13.950609249257713  and Data score  69.54411840537371
# Performance on the validation set  0.9096
# Epoch  65
# Prior score  13.88450641544175  and Data score  71.53480164826018
# Performance on the validation set  0.9094
# Epoch  66
# Prior score  14.04383295018003  and Data score  70.94441448277753
# Performance on the validation set  0.9099
# Epoch  67
# Prior score  13.880632953034528  and Data score  70.6613479879866
# Performance on the validation set  0.9101
# Epoch  68
# Prior score  14.116023350593355  and Data score  69.66317818643593
# Performance on the validation set  0.9079
# Epoch  69
# Prior score  13.565809654975268  and Data score  68.32763641502025
# Performance on the validation set  0.907
# Epoch  70
# Prior score  13.722502773282809  and Data score  66.88330287961769
# Performance on the validation set  0.9097
# Epoch  71
# Prior score  13.812782822792489  and Data score  68.28780023461515
# Performance on the validation set  0.9092
# Epoch  72
# Prior score  13.89286088748499  and Data score  68.24449778663254
# Performance on the validation set  0.9106
# Epoch  73
# Prior score  13.639843589904036  and Data score  69.72784076307734
# Performance on the validation set  0.9082
# Epoch  74
# Prior score  13.838226791850383  and Data score  69.12499701819877
# Performance on the validation set  0.9098
# Epoch  75
# Prior score  13.56888819596415  and Data score  68.75806155316081
# Performance on the validation set  0.9107
# Epoch  76
# Prior score  14.037134692463555  and Data score  66.72303845193012
# Performance on the validation set  0.9101
# Epoch  77
# Prior score  13.717183150619867  and Data score  68.9369525415958
# Performance on the validation set  0.9102
# Epoch  78
# Prior score  13.805766147089571  and Data score  70.75538545097496
# Performance on the validation set  0.9093
# Epoch  79
# Prior score  13.695464163380235  and Data score  67.39454648337917
# Performance on the validation set  0.9057
# Epoch  80
# Prior score  13.927477057763848  and Data score  69.80565707069881
# Performance on the validation set  0.9104
# Epoch  81
# Prior score  13.803833971969535  and Data score  66.94827560190645
# Performance on the validation set  0.9097
# Epoch  82
# Prior score  13.840774633819155  and Data score  71.81593924715003
# Performance on the validation set  0.9096
# Epoch  83
# Prior score  13.98344112900625  and Data score  68.14006954944385
# Performance on the validation set  0.9051
# Epoch  84
# Prior score  13.795356378830425  and Data score  67.73660017718895
# Performance on the validation set  0.9101
# Epoch  85
# Prior score  13.628615693642079  and Data score  67.98813900567143
# Performance on the validation set  0.9102
# Epoch  86
# Prior score  13.953003985666632  and Data score  67.62811789643116
# Performance on the validation set  0.9101
# Epoch  87
# Prior score  13.541378260320954  and Data score  67.40116534074924
# Performance on the validation set  0.9086
# Epoch  88
# Prior score  13.751175447326187  and Data score  68.60258757213396
# Performance on the validation set  0.9044
# Epoch  89
# Prior score  13.830488505320423  and Data score  66.97918495204429
# Performance on the validation set  0.91
# Epoch  90
# Prior score  13.720578747568469  and Data score  66.80547630117712
# Performance on the validation set  0.9076
# Epoch  91
# Prior score  13.812689858764207  and Data score  67.59291506121761
# Performance on the validation set  0.9099
# Epoch  92
# Prior score  13.769261388227957  and Data score  72.0095178773971
# Performance on the validation set  0.9111
# Epoch  93
# Prior score  13.80561019956143  and Data score  72.03065880722718
# Performance on the validation set  0.9079
# Epoch  94
# Prior score  13.695806311270557  and Data score  68.076844315904
# Performance on the validation set  0.9098
# Epoch  95
# Prior score  13.74703648874821  and Data score  67.95436576423839
# Performance on the validation set  0.91
# Epoch  96
# Prior score  13.700309146828799  and Data score  67.52997003118304
# Performance on the validation set  0.9082
# Epoch  97
# Prior score  13.758614766011338  and Data score  67.16554358213014
# Performance on the validation set  0.9103
# Epoch  98
# Prior score  13.810034178902551  and Data score  67.02892072386112
# Performance on the validation set  0.9086
# Epoch  99
# Prior score  13.76942933738863  and Data score  69.6964253694377
# Performance on the validation set  0.91
# Epoch  100
# Prior score  13.888376395438394  and Data score  67.01973522371799
# Performance on the validation set  0.9092
# Time  4
# Epoch  1
# Prior score  10.118011470686772  and Data score  90.79849372602574
# Performance on the validation set  0.8758
# Epoch  2
# Prior score  10.560761858476143  and Data score  79.03514336358243
# Performance on the validation set  0.8785
# Epoch  3
# Prior score  11.227004987314162  and Data score  78.40203874220254
# Performance on the validation set  0.8895
# Epoch  4
# Prior score  11.500324175984101  and Data score  84.03491740549485
# Performance on the validation set  0.8909
# Epoch  5
# Prior score  11.739541603965497  and Data score  75.59000677347282
# Performance on the validation set  0.8898
# Epoch  6
# Prior score  11.852078827580808  and Data score  73.53695480505837
# Performance on the validation set  0.9011
# Epoch  7
# Prior score  12.526009148327462  and Data score  74.65470175892263
# Performance on the validation set  0.9026
# Epoch  8
# Prior score  12.600503626170552  and Data score  71.96787055896327
# Performance on the validation set  0.8987
# Epoch  9
# Prior score  12.479468027062572  and Data score  72.68716632441799
# Performance on the validation set  0.9001
# Epoch  10
# Prior score  12.905962889569356  and Data score  71.4281169118756
# Performance on the validation set  0.902
# Epoch  11
# Prior score  13.155725756578054  and Data score  73.48449316200343
# Performance on the validation set  0.9005
# Epoch  12
# Prior score  12.86931875252999  and Data score  70.37865979823215
# Performance on the validation set  0.9083
# Epoch  13
# Prior score  13.21218293819663  and Data score  78.37898887673462
# Performance on the validation set  0.9059
# Epoch  14
# Prior score  13.18704091141035  and Data score  72.00219069741453
# Performance on the validation set  0.9011
# Epoch  15
# Prior score  13.241327286685845  and Data score  74.32324665343143
# Performance on the validation set  0.9052
# Epoch  16
# Prior score  13.3605426072206  and Data score  74.88626568386672
# Performance on the validation set  0.9074
# Epoch  17
# Prior score  13.400945658132077  and Data score  69.86666305169653
# Performance on the validation set  0.9058
# Epoch  18
# Prior score  13.590919509689517  and Data score  71.27856155174369
# Performance on the validation set  0.9053
# Epoch  19
# Prior score  13.646253384381067  and Data score  73.50602470929411
# Performance on the validation set  0.9072
# Epoch  20
# Prior score  13.46608302995842  and Data score  69.75323660644996
# Performance on the validation set  0.9049
# Epoch  21
# Prior score  13.64345546129016  and Data score  72.93920149797876
# Performance on the validation set  0.9045
# Epoch  22
# Prior score  13.527006544435448  and Data score  73.564839149277
# Performance on the validation set  0.8986
# Epoch  23
# Prior score  13.625878773725322  and Data score  70.92096394618274
# Performance on the validation set  0.9062
# Epoch  24
# Prior score  13.632443285532746  and Data score  70.92135298511802
# Performance on the validation set  0.9009
# Epoch  25
# Prior score  13.683685413858944  and Data score  69.01317763549137
# Performance on the validation set  0.9052
# Epoch  26
# Prior score  13.699044106898485  and Data score  72.56665017895767
# Performance on the validation set  0.908
# Epoch  27
# Prior score  13.666539513464395  and Data score  69.77271900327268
# Performance on the validation set  0.9041
# Epoch  28
# Prior score  13.511595185732526  and Data score  71.42547191521301
# Performance on the validation set  0.9017
# Epoch  29
# Prior score  13.727714636564878  and Data score  68.45433693749023
# Performance on the validation set  0.9064
# Epoch  30
# Prior score  13.965803750568247  and Data score  70.26141545095889
# Performance on the validation set  0.905
# Epoch  31
# Prior score  13.903077050627315  and Data score  72.98969969451072
# Performance on the validation set  0.9059
# Epoch  32
# Prior score  13.731138666019406  and Data score  71.36270734061927
# Performance on the validation set  0.9077
# Epoch  33
# Prior score  13.948029469957236  and Data score  68.80498991863976
# Performance on the validation set  0.9068
# Epoch  34
# Prior score  14.031732494200075  and Data score  72.64063213739702
# Performance on the validation set  0.8997
# Epoch  35
# Prior score  13.722100189871657  and Data score  71.08728112972071
# Performance on the validation set  0.9001
# Epoch  36
# Prior score  13.793839127006558  and Data score  71.87848769634077
# Performance on the validation set  0.9033
# Epoch  37
# Prior score  13.850729541749816  and Data score  72.86311902176597
# Performance on the validation set  0.9035
# Epoch  38
# Prior score  14.145276326063113  and Data score  69.86881765833787
# Performance on the validation set  0.9066
# Epoch  39
# Prior score  13.996750707743045  and Data score  71.9036711371672
# Performance on the validation set  0.9053
# Epoch  40
# Prior score  14.132345332981854  and Data score  73.83926255728984
# Performance on the validation set  0.9056
# Epoch  41
# Prior score  14.093523333401732  and Data score  70.64710354013981
# Performance on the validation set  0.9098
# Epoch  42
# Prior score  13.92127554760947  and Data score  68.72717459351169
# Performance on the validation set  0.9031
# Epoch  43
# Prior score  14.025830644050112  and Data score  70.97342324872541
# Performance on the validation set  0.9116
# Epoch  44
# Prior score  14.026767890145164  and Data score  71.11189738952376
# Performance on the validation set  0.9013
# Epoch  45
# Prior score  13.981054420147002  and Data score  68.17932514734338
# Performance on the validation set  0.9053
# Epoch  46
# Prior score  14.013045697114821  and Data score  71.88510638071853
# Performance on the validation set  0.9046
# Epoch  47
# Prior score  13.910713496265707  and Data score  70.21717450876352
# Performance on the validation set  0.9027
# Epoch  48
# Prior score  13.9721016153561  and Data score  71.1725205381691
# Performance on the validation set  0.9059
# Epoch  49
# Prior score  14.083599141390964  and Data score  67.97130976940936
# Performance on the validation set  0.9071
# Epoch  50
# Prior score  14.321534069354106  and Data score  69.31425335903673
# Performance on the validation set  0.9081
# Epoch  51
# Prior score  14.212655332882981  and Data score  68.94642321591859
# Performance on the validation set  0.9037
# Epoch  52
# Prior score  13.961223541716013  and Data score  69.91236555545582
# Performance on the validation set  0.9048
# Epoch  53
# Prior score  14.04830001025944  and Data score  71.40578826109358
# Performance on the validation set  0.9044
# Epoch  54
# Prior score  14.00157562498945  and Data score  68.07479282199184
# Performance on the validation set  0.9081
# Epoch  55
# Prior score  14.012707606218322  and Data score  72.61455524695488
# Performance on the validation set  0.9016
# Epoch  56
# Prior score  14.021206287448946  and Data score  68.2431778375771
# Performance on the validation set  0.9054
# Epoch  57
# Prior score  13.78256597532945  and Data score  69.3083319426825
# Performance on the validation set  0.9071
# Epoch  58
# Prior score  14.083545928371668  and Data score  74.89808907894452
# Performance on the validation set  0.9033
# Epoch  59
# Prior score  14.04131073712631  and Data score  71.21530902453873
# Performance on the validation set  0.9081
# Epoch  60
# Prior score  13.976880495860323  and Data score  71.41517779760886
# Performance on the validation set  0.9018
# Epoch  61
# Prior score  14.027644928519122  and Data score  70.19816078102829
# Performance on the validation set  0.9104
# Epoch  62
# Prior score  13.952006734439884  and Data score  71.5412683044781
# Performance on the validation set  0.907
# Epoch  63
# Prior score  13.96362000072522  and Data score  69.74642086887059
# Performance on the validation set  0.9069
# Epoch  64
# Prior score  14.013951365178796  and Data score  68.7009878037397
# Performance on the validation set  0.9026
# Epoch  65
# Prior score  13.640997978271521  and Data score  68.69488269760437
# Performance on the validation set  0.9033
# Epoch  66
# Prior score  14.080302745060745  and Data score  68.61336559575606
# Performance on the validation set  0.9071
# Epoch  67
# Prior score  13.795357659517231  and Data score  69.18931441624758
# Performance on the validation set  0.9048
# Epoch  68
# Prior score  13.824860525652863  and Data score  68.30349485772628
# Performance on the validation set  0.9081
# Epoch  69
# Prior score  13.81052311804863  and Data score  73.49107294384139
# Performance on the validation set  0.8985
# Epoch  70
# Prior score  13.99869536272213  and Data score  71.79004530022516
# Performance on the validation set  0.9024
# Epoch  71
# Prior score  14.03192097724544  and Data score  68.92084013557341
# Performance on the validation set  0.9038
# Epoch  72
# Prior score  14.148549814845495  and Data score  67.24394477191314
# Performance on the validation set  0.9072
# Epoch  73
# Prior score  13.898948190246902  and Data score  68.18282721654333
# Performance on the validation set  0.9053
# Epoch  74
# Prior score  13.98594151675681  and Data score  67.55312151855195
# Performance on the validation set  0.908
# Epoch  75
# Prior score  13.916819609372505  and Data score  69.01055784594955
# Performance on the validation set  0.9112
# Epoch  76
# Prior score  14.027014907343782  and Data score  70.19405782469235
# Performance on the validation set  0.9083
# Epoch  77
# Prior score  13.836977494490807  and Data score  69.12716350786175
# Performance on the validation set  0.9121
# Epoch  78
# Prior score  14.125427954536532  and Data score  72.35084332498977
# Performance on the validation set  0.9051
# Epoch  79
# Prior score  13.785385984636433  and Data score  69.83509043771018
# Performance on the validation set  0.9052
# Epoch  80
# Prior score  14.04797076790669  and Data score  67.6993902614898
# Performance on the validation set  0.9053
# Epoch  81
# Prior score  13.927933676622256  and Data score  69.89104743484819
# Performance on the validation set  0.9079
# Epoch  82
# Prior score  13.89226895347053  and Data score  76.69670960103306
# Performance on the validation set  0.9045
# Epoch  83
# Prior score  13.969975591390693  and Data score  68.4444857023575
# Performance on the validation set  0.9053
# Epoch  84
# Prior score  14.048219641874326  and Data score  67.77266502750707
# Performance on the validation set  0.9111
# Epoch  85
# Prior score  13.917718490631911  and Data score  69.56148163291233
# Performance on the validation set  0.9024
# Epoch  86
# Prior score  13.878357618113242  and Data score  71.16652245541098
# Performance on the validation set  0.9056
# Epoch  87
# Prior score  14.066817558876501  and Data score  68.83982846998775
# Performance on the validation set  0.9059
# Epoch  88
# Prior score  14.0127684020477  and Data score  68.61512256882062
# Performance on the validation set  0.9042
# Epoch  89
# Prior score  14.072335751049977  and Data score  67.93802328749202
# Performance on the validation set  0.9067
# Epoch  90
# Prior score  13.824442475070605  and Data score  72.16841804844483
# Performance on the validation set  0.9055
# Epoch  91
# Prior score  14.019351304011439  and Data score  69.88710311295182
# Performance on the validation set  0.8999
# Epoch  92
# Prior score  14.054124575248888  and Data score  70.33558676628739
# Performance on the validation set  0.8999
# Epoch  93
# Prior score  13.897223803168412  and Data score  69.71683448790564
# Performance on the validation set  0.9042
# Epoch  94
# Prior score  13.820106918881773  and Data score  71.20056917488813
# Performance on the validation set  0.9068
# Epoch  95
# Prior score  13.9624684014818  and Data score  70.94199182599287
# Performance on the validation set  0.904
# Epoch  96
# Prior score  14.127499424291441  and Data score  71.10117344614159
# Performance on the validation set  0.9085
# Epoch  97
# Prior score  14.146549291356287  and Data score  69.32224516458483
# Performance on the validation set  0.9079
# Epoch  98
# Prior score  14.09032616313425  and Data score  68.69524164688214
# Performance on the validation set  0.9009
# Epoch  99
# Prior score  14.25207597914307  and Data score  69.3147543428789
# Performance on the validation set  0.908
# Epoch  100
# Prior score  14.103116020883522  and Data score  71.16454495823407
# Performance on the validation set  0.9112
# Time  5
# Epoch  1
# Prior score  9.922000459981017  and Data score  92.73676956982017
# Performance on the validation set  0.8835
# Epoch  2
# Prior score  10.80690327939301  and Data score  82.28257017443359
# Performance on the validation set  0.889
# Epoch  3
# Prior score  11.324429402415348  and Data score  76.6989404320208
# Performance on the validation set  0.8973
# Epoch  4
# Prior score  11.835770845704163  and Data score  75.22293645467143
# Performance on the validation set  0.8975
# Epoch  5
# Prior score  12.196789000349145  and Data score  78.00817013293538
# Performance on the validation set  0.9001
# Epoch  6
# Prior score  12.316506845498521  and Data score  73.293440545256
# Performance on the validation set  0.9046
# Epoch  7
# Prior score  12.716713103876872  and Data score  76.5550371063052
# Performance on the validation set  0.9078
# Epoch  8
# Prior score  12.873789853630631  and Data score  70.9731169799418
# Performance on the validation set  0.8989
# Epoch  9
# Prior score  12.811173260528957  and Data score  72.63790961457579
# Performance on the validation set  0.9045
# Epoch  10
# Prior score  12.79180344935656  and Data score  74.2568256347994
# Performance on the validation set  0.9021
# Epoch  11
# Prior score  12.972481141417788  and Data score  77.28847417548361
# Performance on the validation set  0.9035
# Epoch  12
# Prior score  13.158013932284966  and Data score  73.84965240891877
# Performance on the validation set  0.9048
# Epoch  13
# Prior score  13.266018600839155  and Data score  74.55341353958748
# Performance on the validation set  0.9073
# Epoch  14
# Prior score  13.2770289456521  and Data score  74.46503249380552
# Performance on the validation set  0.9047
# Epoch  15
# Prior score  13.153167862529582  and Data score  70.299013567684
# Performance on the validation set  0.9066
# Epoch  16
# Prior score  13.362906477290716  and Data score  71.5356578162247
# Performance on the validation set  0.9091
# Epoch  17
# Prior score  13.438038973613416  and Data score  70.24671494840797
# Performance on the validation set  0.9051
# Epoch  18
# Prior score  13.429685594391753  and Data score  73.36563923762643
# Performance on the validation set  0.9063
# Epoch  19
# Prior score  13.474375565368854  and Data score  71.90981174355899
# Performance on the validation set  0.9064
# Epoch  20
# Prior score  13.533059620076733  and Data score  71.0433309569385
# Performance on the validation set  0.9057
# Epoch  21
# Prior score  13.348534166676037  and Data score  70.67852224716519
# Performance on the validation set  0.9052
# Epoch  22
# Prior score  13.443941355781895  and Data score  68.5582663017255
# Performance on the validation set  0.907
# Epoch  23
# Prior score  13.725480644208286  and Data score  73.29034755444357
# Performance on the validation set  0.9086
# Epoch  24
# Prior score  13.440067706740866  and Data score  69.87548977851414
# Performance on the validation set  0.9075
# Epoch  25
# Prior score  13.413182972804949  and Data score  70.74628419375072
# Performance on the validation set  0.9086
# Epoch  26
# Prior score  13.585036442785722  and Data score  72.72040034862411
# Performance on the validation set  0.9003
# Epoch  27
# Prior score  13.596537465151332  and Data score  70.88786690362912
# Performance on the validation set  0.9079
# Epoch  28
# Prior score  13.410700933713562  and Data score  69.27778805432085
# Performance on the validation set  0.9083
# Epoch  29
# Prior score  13.661177935216124  and Data score  71.42071890135408
# Performance on the validation set  0.9083
# Epoch  30
# Prior score  13.537601994850034  and Data score  70.84199632785852
# Performance on the validation set  0.9065
# Epoch  31
# Prior score  13.670429149644475  and Data score  73.51502991638561
# Performance on the validation set  0.9078
# Epoch  32
# Prior score  13.730955480673016  and Data score  69.06700501288681
# Performance on the validation set  0.909
# Epoch  33
# Prior score  13.546340008532772  and Data score  71.68625972917926
# Performance on the validation set  0.9072
# Epoch  34
# Prior score  13.760970275206374  and Data score  73.32830756708339
# Performance on the validation set  0.9045
# Epoch  35
# Prior score  13.732776932246228  and Data score  68.95892641778633
# Performance on the validation set  0.9082
# Epoch  36
# Prior score  13.533767226848562  and Data score  72.71786206821416
# Performance on the validation set  0.9075
# Epoch  37
# Prior score  13.42507546773626  and Data score  70.5703205210439
# Performance on the validation set  0.905
# Epoch  38
# Prior score  13.461717189035921  and Data score  70.99933231392343
# Performance on the validation set  0.9092
# Epoch  39
# Prior score  13.562430805882167  and Data score  73.05149231128239
# Performance on the validation set  0.9081
# Epoch  40
# Prior score  13.662734339627013  and Data score  69.71685352937114
# Performance on the validation set  0.9085
# Epoch  41
# Prior score  13.794435471260412  and Data score  69.28227735954086
# Performance on the validation set  0.9077
# Epoch  42
# Prior score  13.598264170797739  and Data score  71.5777909039936
# Performance on the validation set  0.908
# Epoch  43
# Prior score  13.752586010252195  and Data score  69.98316465505576
# Performance on the validation set  0.9075
# Epoch  44
# Prior score  13.904883094446367  and Data score  72.14090412414642
# Performance on the validation set  0.9076
# Epoch  45
# Prior score  13.860361131407894  and Data score  69.78570755111016
# Performance on the validation set  0.9089
# Epoch  46
# Prior score  13.702709501368826  and Data score  71.28744437728618
# Performance on the validation set  0.9077
# Epoch  47
# Prior score  13.832312781052947  and Data score  68.24316155960173
# Performance on the validation set  0.9061
# Epoch  48
# Prior score  13.932435694117467  and Data score  68.78269213237725
# Performance on the validation set  0.9089
# Epoch  49
# Prior score  13.909776351488325  and Data score  67.80496200108377
# Performance on the validation set  0.9068
# Epoch  50
# Prior score  13.442010635686133  and Data score  69.709855961622
# Performance on the validation set  0.9089
# Epoch  51
# Prior score  13.761346036922033  and Data score  69.91928264708146
# Performance on the validation set  0.907
# Epoch  52
# Prior score  13.756867478226253  and Data score  70.35861983109224
# Performance on the validation set  0.9082
# Epoch  53
# Prior score  13.917512922049676  and Data score  69.01448331079574
# Performance on the validation set  0.9062
# Epoch  54
# Prior score  13.699317504526189  and Data score  71.57151382098756
# Performance on the validation set  0.9091
# Epoch  55
# Prior score  13.645833463383173  and Data score  71.54071322310426
# Performance on the validation set  0.9079
# Epoch  56
# Prior score  13.853802428574  and Data score  69.06011289848368
# Performance on the validation set  0.9039
# Epoch  57
# Prior score  13.685029448336241  and Data score  71.27874540806185
# Performance on the validation set  0.9085
# Epoch  58
# Prior score  13.716382188167731  and Data score  68.35720980115941
# Performance on the validation set  0.9079
# Epoch  59
# Prior score  13.742049391603137  and Data score  67.34703050870496
# Performance on the validation set  0.9086
# Epoch  60
# Prior score  13.50384703625296  and Data score  68.33379446065676
# Performance on the validation set  0.9099
# Epoch  61
# Prior score  13.996120119595206  and Data score  72.3656161257561
# Performance on the validation set  0.9082
# Epoch  62
# Prior score  13.51199194621582  and Data score  69.92047791054208
# Performance on the validation set  0.9076
# Epoch  63
# Prior score  13.64266727027037  and Data score  71.10701744771778
# Performance on the validation set  0.9088
# Epoch  64
# Prior score  13.433287451681531  and Data score  72.33593906647253
# Performance on the validation set  0.9079
# Epoch  65
# Prior score  13.569073364008199  and Data score  69.03530852929191
# Performance on the validation set  0.9045
# Epoch  66
# Prior score  13.421099144945535  and Data score  71.0045399948371
# Performance on the validation set  0.9094
# Epoch  67
# Prior score  13.737055533233114  and Data score  66.59559326295211
# Performance on the validation set  0.9058
# Epoch  68
# Prior score  13.825418581106574  and Data score  70.14054474998454
# Performance on the validation set  0.9068
# Epoch  69
# Prior score  13.89910253051992  and Data score  70.33712461997143
# Performance on the validation set  0.9085
# Epoch  70
# Prior score  13.501956110651909  and Data score  68.83116123640207
# Performance on the validation set  0.9073
# Epoch  71
# Prior score  13.536062933227699  and Data score  69.12203217164323
# Performance on the validation set  0.909
# Epoch  72
# Prior score  13.685017003769598  and Data score  73.99992247678259
# Performance on the validation set  0.9088
# Epoch  73
# Prior score  13.665795601029012  and Data score  70.51962978884507
# Performance on the validation set  0.908
# Epoch  74
# Prior score  13.826277642499898  and Data score  69.18040833131288
# Performance on the validation set  0.9059
# Epoch  75
# Prior score  13.691334928369992  and Data score  66.4468534289046
# Performance on the validation set  0.9085
# Epoch  76
# Prior score  14.060008625352662  and Data score  72.2670532862522
# Performance on the validation set  0.9086
# Epoch  77
# Prior score  13.89778384853266  and Data score  67.72113265524504
# Performance on the validation set  0.905
# Epoch  78
# Prior score  14.018090371935486  and Data score  69.1399266891941
# Performance on the validation set  0.907
# Epoch  79
# Prior score  13.99975183720112  and Data score  71.00922334351144
# Performance on the validation set  0.9083
# Epoch  80
# Prior score  13.830385768274342  and Data score  68.48828590359544
# Performance on the validation set  0.9094
# Epoch  81
# Prior score  13.755062967985968  and Data score  68.31034145209046
# Performance on the validation set  0.9086
# Epoch  82
# Prior score  13.590131850456102  and Data score  68.04166503111797
# Performance on the validation set  0.9086
# Epoch  83
# Prior score  13.691811559197337  and Data score  67.6681002923905
# Performance on the validation set  0.9064
# Epoch  84
# Prior score  13.534305916561143  and Data score  67.40212976131961
# Performance on the validation set  0.9104
# Epoch  85
# Prior score  13.632977953711828  and Data score  70.59361526057984
# Performance on the validation set  0.9077
# Epoch  86
# Prior score  13.665113072167001  and Data score  74.98225336821328
# Performance on the validation set  0.909
# Epoch  87
# Prior score  13.770184049872633  and Data score  70.77046090988463
# Performance on the validation set  0.9074
# Epoch  88
# Prior score  13.49773570352937  and Data score  67.6077997110683
# Performance on the validation set  0.9066
# Epoch  89
# Prior score  13.793081646776123  and Data score  72.32487536310683
# Performance on the validation set  0.9084
# Epoch  90
# Prior score  13.680115822832878  and Data score  67.5084089500015
# Performance on the validation set  0.9068
# Epoch  91
# Prior score  13.717985529605722  and Data score  74.25255170512659
# Performance on the validation set  0.9085
# Epoch  92
# Prior score  13.641297548180832  and Data score  71.78785505711285
# Performance on the validation set  0.9104
# Epoch  93
# Prior score  13.448612929652246  and Data score  69.31462556142488
# Performance on the validation set  0.9085
# Epoch  94
# Prior score  13.564880584088565  and Data score  70.12190879329225
# Performance on the validation set  0.9085
# Epoch  95
# Prior score  13.671636229351103  and Data score  68.93875195039524
# Performance on the validation set  0.9077
# Epoch  96
# Prior score  13.794062636442268  and Data score  70.98748444237637
# Performance on the validation set  0.907
# Epoch  97
# Prior score  13.76693151427975  and Data score  69.73825204380194
# Performance on the validation set  0.9077
# Epoch  98
# Prior score  13.83355212764424  and Data score  70.10454835612697
# Performance on the validation set  0.9076
# Epoch  99
# Prior score  13.800832426648244  and Data score  69.52952421176981
# Performance on the validation set  0.9096
# Epoch  100
# Prior score  13.730668599788741  and Data score  69.92052775714946
# Performance on the validation set  0.9089

# %%
# Create the figure and 3D axis
fig, axes = plt.subplots(1, 5, figsize=(25, 5), subplot_kw={'projection': '3d'})


for i, ax in enumerate(axes):
	t=i

	x_sample = X[t*sample_size:(t*sample_size+sample_size),0]
	y_sample = X[t*sample_size:(t*sample_size+sample_size),1]

	grid_size = 50
	x_grid = np.linspace(np.min(x_sample), np.max(x_sample), grid_size)
	y_grid = np.linspace(np.min(y_sample), np.max(y_sample), grid_size)

	x_grid, y_grid = np.meshgrid(x_grid, y_grid)

	x_1 = np.reshape(x_grid, (grid_size*grid_size))
	x_2 = np.reshape(y_grid, (grid_size*grid_size))

	X_test = np.stack((x_1, x_2), axis = -1)

	perf_sample_list = []
	for s in range(50):
		output = HMMNET.model_list[t+1].forward( torch.tensor(X_test, dtype = torch.float64 ) )
		output_softmax   = F.softmax(output, dim=1)
		perf_sample = np.reshape(output_softmax[:,1].detach().numpy(), (grid_size, grid_size))
		perf_sample_list.append(perf_sample)

	Z_quantiles = np.quantile(np.stack(perf_sample_list, axis = -1), (0.025, 0.975), axis = -1)
	Z_upper = Z_quantiles[1,...]
	Z_lower = Z_quantiles[0,...]

	output = HMMNET.model_list[t+1].performance( torch.tensor(X_test, dtype = torch.float64 ) )
	output_softmax   = F.softmax(output, dim=1)
	Z = np.reshape(output_softmax[:,1].detach().numpy(), (grid_size, grid_size))

	# Plot the main surface
	surf = ax.plot_surface(x_grid, y_grid, Z, cmap='viridis', alpha=0.8, label="Main Surface")

	# Plot the confidence bands (upper and lower surfaces)
	ax.plot_surface(x_grid, y_grid, Z_upper, color='lightblue', alpha=0.5, label="Upper Confidence Band")
	ax.plot_surface(x_grid, y_grid, Z_lower, color='lightpink', alpha=0.5, label="Lower Confidence Band")

	ax.view_init(elev=45, azim=45)

	ax.set_title("Time "+str(t))
	# ax.set_xlabel(r'x')
	# ax.set_ylabel(r'y')
	# ax.set_zlabel('prob.', labelpad=5, rotation=0)

	# if i ==0:
	# 	ax.set_zlabel(r'prob')

# Adjust layout and show the figure
plt.tight_layout()
plt.show()


plt.savefig('moonoverlap_surface.png', dpi=100)

# %%
# Create the figure and 3D axis
fig, axes = plt.subplots(1, 5, figsize=(30, 5))


for i, ax in enumerate(axes):
	t=i

	x_sample = X[t*sample_size:(t*sample_size+sample_size),0]
	y_sample = X[t*sample_size:(t*sample_size+sample_size),1]
	label_sample = y[t*sample_size:(t*sample_size+sample_size)]

	grid_size = 50
	x_grid = np.linspace(np.min(x_sample), np.max(x_sample), grid_size)
	y_grid = np.linspace(np.min(y_sample), np.max(y_sample), grid_size)

	x_grid, y_grid = np.meshgrid(x_grid, y_grid)

	x_1 = np.reshape(x_grid, (grid_size*grid_size))
	x_2 = np.reshape(y_grid, (grid_size*grid_size))

	X_test = np.stack((x_1, x_2), axis = -1)

	perf_sample_list = []
	for s in range(50):
		output = HMMNET.model_list[t+1].forward( torch.tensor(X_test, dtype = torch.float64 ) )
		output_softmax   = F.softmax(output, dim=1)
		perf_sample = np.reshape(output_softmax[:,1].detach().numpy(), (grid_size, grid_size))
		perf_sample_list.append(perf_sample)

	Z_quantiles = np.quantile(np.stack(perf_sample_list, axis = -1), (0.025, 0.975), axis = -1)
	Z_upper = Z_quantiles[1,...]
	Z_lower = Z_quantiles[0,...]

	# Filled contour plot
	contour = ax.contourf(x_grid, y_grid, Z_upper -Z_lower, levels=20, cmap='viridis')  # 'viridis' colormap
	plt.colorbar(contour)  # Add a color bar
	ax.scatter(x_sample[:300], y_sample[:300], c = np.array(["red", "black"])[label_sample[:300]])

	# ax.set_xlabel("x")
	ax.set_title("Time "+str(t))
	
	# if i ==0:
	# 	ax.set_ylabel(r'y')

# Adjust layout and show the figure
plt.tight_layout()
plt.show()

plt.savefig('moonoverlap_ci.png', dpi=100)
